# %%
from pathlib import Path
import sys

from IPython.display import Image, display

workspace_root = Path.cwd().parent
if str(workspace_root) not in sys.path:
    sys.path.insert(0, str(workspace_root))

from graph.workflow import build_resume_graph

app = build_resume_graph()
graph = app.get_graph()

output_dir = Path.cwd()
mermaid_path = output_dir / "workflow.mmd"
png_path = output_dir / "workflow.png"

mermaid_text = graph.draw_mermaid()
mermaid_path.write_text(mermaid_text, encoding="utf-8")

png_bytes = graph.draw_mermaid_png()
png_path.write_bytes(png_bytes)

display(Image(filename=str(png_path)))
print(f"Saved Mermaid diagram to: {mermaid_path}")
print(f"Saved PNG diagram to: {png_path}")
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (7.4.3)/charset_normalizer (3.4.2) doesn't match a supported version!
#   warnings.warn(
# 2026-04-29 23:36:15,010 - graph.workflow - INFO - Building resume optimization workflow graph
# 2026-04-29 23:36:15,024 - graph.workflow - INFO - Workflow graph built successfully
# Saved Mermaid diagram to: x:\Agentic Resume Optimizer\graph\workflow.mmd
# Saved PNG diagram to: x:\Agentic Resume Optimizer\graph\workflow.png
